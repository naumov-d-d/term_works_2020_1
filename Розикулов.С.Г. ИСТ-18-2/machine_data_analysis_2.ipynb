# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>cp</th>
#       <th>trestbps</th>
#       <th>chol</th>
#       <th>fbs</th>
#       <th>restecg</th>
#       <th>thalach</th>
#       <th>exang</th>
#       <th>oldpeak</th>
#       <th>slope</th>
#       <th>ca</th>
#       <th>num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.927622</td>
#       <td>1.0</td>
#       <td>1.000000</td>
#       <td>0.624287</td>
#       <td>-0.206993</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>0.090789</td>
#       <td>0.0</td>
#       <td>0.552201</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-2.117138</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.454038</td>
#       <td>0.159591</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.444548</td>
#       <td>0.0</td>
#       <td>0.715169</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1.529863</td>
#       <td>0.0</td>
#       <td>0.577350</td>
#       <td>0.454038</td>
#       <td>-0.864692</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.931137</td>
#       <td>0.0</td>
#       <td>0.398844</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.253797</td>
#       <td>1.0</td>
#       <td>0.577350</td>
#       <td>0.335019</td>
#       <td>-0.141353</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.141680</td>
#       <td>0.0</td>
#       <td>0.265991</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.355054</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.335019</td>
#       <td>2.100829</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.601134</td>
#       <td>1.0</td>
#       <td>0.210865</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.355054</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>0.568560</td>
#       <td>-1.150460</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.008368</td>
#       <td>0.0</td>
#       <td>0.145476</td>
#       <td>0.707107</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.253797</td>
#       <td>0.0</td>
#       <td>0.577350</td>
#       <td>0.568560</td>
#       <td>1.054214</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.212382</td>
#       <td>0.0</td>
#       <td>0.379044</td>
#       <td>0.707107</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-1.125867</td>
#       <td>1.0</td>
#       <td>0.577350</td>
#       <td>0.335019</td>
#       <td>0.431579</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.966733</td>
#       <td>0.0</td>
#       <td>0.323580</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.170168</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.909866</td>
#       <td>-0.982712</td>
#       <td>1.0</td>
#       <td>0.397544</td>
#       <td>0.563348</td>
#       <td>0.0</td>
#       <td>0.179818</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.355054</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.679061</td>
#       <td>-1.750157</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.002123</td>
#       <td>0.0</td>
#       <td>0.436427</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
X = dataset.iloc[:, [*range(1,13),12]].values
Y = dataset['age'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
input_layer_size = 13
first_hidden_layer_size = 12
second_hidden_layer_size = 12
output_layer_size = 1
epochs_number = 50
batch_size = 4

# %%
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - sigmoid
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='sigmoid'))

model.add(Dense(second_hidden_layer_size, activation='sigmoid'))

model.add(Dense(output_layer_size, activation='linear'))

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 242 samples, validate on 61 samples
# Epoch 1/50
# 242/242 [==============================] - 0s 860us/step - loss: 1.9583 - mean_absolute_error: 1.0728 - mean_squared_error: 1.9583 - val_loss: 1.8240 - val_mean_absolute_error: 1.0019 - val_mean_squared_error: 1.8240
# Epoch 2/50
# 242/242 [==============================] - 0s 302us/step - loss: 1.2343 - mean_absolute_error: 0.8422 - mean_squared_error: 1.2343 - val_loss: 1.3059 - val_mean_absolute_error: 0.8772 - val_mean_squared_error: 1.3059
# Epoch 3/50
# 242/242 [==============================] - 0s 296us/step - loss: 1.0224 - mean_absolute_error: 0.7879 - mean_squared_error: 1.0224 - val_loss: 1.1404 - val_mean_absolute_error: 0.8597 - val_mean_squared_error: 1.1404
# Epoch 4/50
# 242/242 [==============================] - 0s 300us/step - loss: 0.9665 - mean_absolute_error: 0.7764 - mean_squared_error: 0.9665 - val_loss: 1.0813 - val_mean_absolute_error: 0.8554 - val_mean_squared_error: 1.0813
# Epoch 5/50
# 242/242 [==============================] - 0s 300us/step - loss: 0.9502 - mean_absolute_error: 0.7802 - mean_squared_error: 0.9502 - val_loss: 1.0495 - val_mean_absolute_error: 0.8506 - val_mean_squared_error: 1.0495
# Epoch 6/50
# 242/242 [==============================] - 0s 301us/step - loss: 0.9367 - mean_absolute_error: 0.7757 - mean_squared_error: 0.9367 - val_loss: 1.0371 - val_mean_absolute_error: 0.8454 - val_mean_squared_error: 1.0371
# Epoch 7/50
# 242/242 [==============================] - 0s 301us/step - loss: 0.9238 - mean_absolute_error: 0.7688 - mean_squared_error: 0.9238 - val_loss: 1.0314 - val_mean_absolute_error: 0.8399 - val_mean_squared_error: 1.0314
# Epoch 8/50
# 242/242 [==============================] - 0s 306us/step - loss: 0.9127 - mean_absolute_error: 0.7641 - mean_squared_error: 0.9127 - val_loss: 1.0152 - val_mean_absolute_error: 0.8339 - val_mean_squared_error: 1.0152
# Epoch 9/50
# 242/242 [==============================] - 0s 316us/step - loss: 0.9010 - mean_absolute_error: 0.7573 - mean_squared_error: 0.9010 - val_loss: 1.0052 - val_mean_absolute_error: 0.8275 - val_mean_squared_error: 1.0052
# Epoch 10/50
# 242/242 [==============================] - 0s 306us/step - loss: 0.8857 - mean_absolute_error: 0.7523 - mean_squared_error: 0.8857 - val_loss: 0.9978 - val_mean_absolute_error: 0.8207 - val_mean_squared_error: 0.9978
# Epoch 11/50
# 242/242 [==============================] - 0s 300us/step - loss: 0.8740 - mean_absolute_error: 0.7473 - mean_squared_error: 0.8740 - val_loss: 0.9848 - val_mean_absolute_error: 0.8158 - val_mean_squared_error: 0.9848
# Epoch 12/50
# 242/242 [==============================] - 0s 301us/step - loss: 0.8603 - mean_absolute_error: 0.7422 - mean_squared_error: 0.8603 - val_loss: 0.9754 - val_mean_absolute_error: 0.8093 - val_mean_squared_error: 0.9754
# Epoch 13/50
# 242/242 [==============================] - 0s 302us/step - loss: 0.8528 - mean_absolute_error: 0.7372 - mean_squared_error: 0.8528 - val_loss: 0.9654 - val_mean_absolute_error: 0.8045 - val_mean_squared_error: 0.9654
# Epoch 14/50
# 242/242 [==============================] - 0s 304us/step - loss: 0.8350 - mean_absolute_error: 0.7301 - mean_squared_error: 0.8350 - val_loss: 0.9644 - val_mean_absolute_error: 0.7985 - val_mean_squared_error: 0.9644
# Epoch 15/50
# 242/242 [==============================] - 0s 309us/step - loss: 0.8212 - mean_absolute_error: 0.7255 - mean_squared_error: 0.8212 - val_loss: 0.9433 - val_mean_absolute_error: 0.7940 - val_mean_squared_error: 0.9433
# Epoch 16/50
# 242/242 [==============================] - 0s 302us/step - loss: 0.8087 - mean_absolute_error: 0.7199 - mean_squared_error: 0.8087 - val_loss: 0.9430 - val_mean_absolute_error: 0.7882 - val_mean_squared_error: 0.9430
# Epoch 17/50
# 242/242 [==============================] - 0s 306us/step - loss: 0.7972 - mean_absolute_error: 0.7146 - mean_squared_error: 0.7972 - val_loss: 0.9316 - val_mean_absolute_error: 0.7836 - val_mean_squared_error: 0.9316
# Epoch 18/50
# 242/242 [==============================] - 0s 298us/step - loss: 0.7877 - mean_absolute_error: 0.7128 - mean_squared_error: 0.7877 - val_loss: 0.9293 - val_mean_absolute_error: 0.7817 - val_mean_squared_error: 0.9293
# Epoch 19/50
# 242/242 [==============================] - 0s 303us/step - loss: 0.7765 - mean_absolute_error: 0.7059 - mean_squared_error: 0.7765 - val_loss: 0.9277 - val_mean_absolute_error: 0.7792 - val_mean_squared_error: 0.9277
# Epoch 20/50
# 242/242 [==============================] - 0s 299us/step - loss: 0.7672 - mean_absolute_error: 0.7024 - mean_squared_error: 0.7672 - val_loss: 0.9155 - val_mean_absolute_error: 0.7758 - val_mean_squared_error: 0.9155
# Epoch 21/50
# 242/242 [==============================] - 0s 303us/step - loss: 0.7580 - mean_absolute_error: 0.6990 - mean_squared_error: 0.7580 - val_loss: 0.9163 - val_mean_absolute_error: 0.7749 - val_mean_squared_error: 0.9163
# Epoch 22/50
# 242/242 [==============================] - 0s 297us/step - loss: 0.7499 - mean_absolute_error: 0.6959 - mean_squared_error: 0.7499 - val_loss: 0.9043 - val_mean_absolute_error: 0.7711 - val_mean_squared_error: 0.9043
# Epoch 23/50
# 242/242 [==============================] - 0s 306us/step - loss: 0.7419 - mean_absolute_error: 0.6934 - mean_squared_error: 0.7419 - val_loss: 0.9133 - val_mean_absolute_error: 0.7714 - val_mean_squared_error: 0.9133
# Epoch 24/50
# 242/242 [==============================] - 0s 308us/step - loss: 0.7350 - mean_absolute_error: 0.6879 - mean_squared_error: 0.7350 - val_loss: 0.9066 - val_mean_absolute_error: 0.7685 - val_mean_squared_error: 0.9066
# Epoch 25/50
# 242/242 [==============================] - 0s 303us/step - loss: 0.7281 - mean_absolute_error: 0.6864 - mean_squared_error: 0.7281 - val_loss: 0.9001 - val_mean_absolute_error: 0.7653 - val_mean_squared_error: 0.9001
# Epoch 26/50
# 242/242 [==============================] - 0s 303us/step - loss: 0.7224 - mean_absolute_error: 0.6838 - mean_squared_error: 0.7224 - val_loss: 0.8839 - val_mean_absolute_error: 0.7603 - val_mean_squared_error: 0.8839
# Epoch 27/50
# 242/242 [==============================] - 0s 303us/step - loss: 0.7187 - mean_absolute_error: 0.6831 - mean_squared_error: 0.7187 - val_loss: 0.8873 - val_mean_absolute_error: 0.7594 - val_mean_squared_error: 0.8873
# Epoch 28/50
# 242/242 [==============================] - 0s 300us/step - loss: 0.7122 - mean_absolute_error: 0.6799 - mean_squared_error: 0.7122 - val_loss: 0.8810 - val_mean_absolute_error: 0.7562 - val_mean_squared_error: 0.8810
# Epoch 29/50
# 242/242 [==============================] - 0s 308us/step - loss: 0.7075 - mean_absolute_error: 0.6772 - mean_squared_error: 0.7075 - val_loss: 0.8753 - val_mean_absolute_error: 0.7527 - val_mean_squared_error: 0.8753
# Epoch 30/50
# 242/242 [==============================] - 0s 307us/step - loss: 0.7061 - mean_absolute_error: 0.6747 - mean_squared_error: 0.7061 - val_loss: 0.8603 - val_mean_absolute_error: 0.7485 - val_mean_squared_error: 0.8603
# Epoch 31/50
# 242/242 [==============================] - 0s 303us/step - loss: 0.7004 - mean_absolute_error: 0.6720 - mean_squared_error: 0.7004 - val_loss: 0.8731 - val_mean_absolute_error: 0.7498 - val_mean_squared_error: 0.8731
# Epoch 32/50
# 242/242 [==============================] - 0s 309us/step - loss: 0.6961 - mean_absolute_error: 0.6748 - mean_squared_error: 0.6961 - val_loss: 0.8694 - val_mean_absolute_error: 0.7475 - val_mean_squared_error: 0.8694
# Epoch 33/50
# 242/242 [==============================] - 0s 306us/step - loss: 0.6909 - mean_absolute_error: 0.6687 - mean_squared_error: 0.6909 - val_loss: 0.8773 - val_mean_absolute_error: 0.7487 - val_mean_squared_error: 0.8773
# Epoch 34/50
# 242/242 [==============================] - 0s 369us/step - loss: 0.6866 - mean_absolute_error: 0.6679 - mean_squared_error: 0.6866 - val_loss: 0.8624 - val_mean_absolute_error: 0.7429 - val_mean_squared_error: 0.8624
# Epoch 35/50
# 242/242 [==============================] - 0s 315us/step - loss: 0.6838 - mean_absolute_error: 0.6658 - mean_squared_error: 0.6838 - val_loss: 0.8611 - val_mean_absolute_error: 0.7416 - val_mean_squared_error: 0.8611
# Epoch 36/50
# 242/242 [==============================] - 0s 310us/step - loss: 0.6821 - mean_absolute_error: 0.6667 - mean_squared_error: 0.6821 - val_loss: 0.8685 - val_mean_absolute_error: 0.7428 - val_mean_squared_error: 0.8685
# Epoch 37/50
# 242/242 [==============================] - 0s 311us/step - loss: 0.6780 - mean_absolute_error: 0.6619 - mean_squared_error: 0.6780 - val_loss: 0.8643 - val_mean_absolute_error: 0.7408 - val_mean_squared_error: 0.8643
# Epoch 38/50
# 242/242 [==============================] - 0s 311us/step - loss: 0.6810 - mean_absolute_error: 0.6595 - mean_squared_error: 0.6810 - val_loss: 0.8346 - val_mean_absolute_error: 0.7298 - val_mean_squared_error: 0.8346
# Epoch 39/50
# 242/242 [==============================] - 0s 309us/step - loss: 0.6805 - mean_absolute_error: 0.6642 - mean_squared_error: 0.6805 - val_loss: 0.8479 - val_mean_absolute_error: 0.7339 - val_mean_squared_error: 0.8479
# Epoch 40/50
# 242/242 [==============================] - 0s 310us/step - loss: 0.6694 - mean_absolute_error: 0.6581 - mean_squared_error: 0.6694 - val_loss: 0.8334 - val_mean_absolute_error: 0.7278 - val_mean_squared_error: 0.8334
# Epoch 41/50
# 242/242 [==============================] - 0s 306us/step - loss: 0.6689 - mean_absolute_error: 0.6579 - mean_squared_error: 0.6689 - val_loss: 0.8474 - val_mean_absolute_error: 0.7323 - val_mean_squared_error: 0.8473
# Epoch 42/50
# 242/242 [==============================] - 0s 301us/step - loss: 0.6692 - mean_absolute_error: 0.6597 - mean_squared_error: 0.6692 - val_loss: 0.8616 - val_mean_absolute_error: 0.7372 - val_mean_squared_error: 0.8616
# Epoch 43/50
# 242/242 [==============================] - 0s 302us/step - loss: 0.6636 - mean_absolute_error: 0.6578 - mean_squared_error: 0.6636 - val_loss: 0.8358 - val_mean_absolute_error: 0.7264 - val_mean_squared_error: 0.8358
# Epoch 44/50
# 242/242 [==============================] - 0s 304us/step - loss: 0.6643 - mean_absolute_error: 0.6538 - mean_squared_error: 0.6643 - val_loss: 0.8398 - val_mean_absolute_error: 0.7274 - val_mean_squared_error: 0.8398
# Epoch 45/50
# 242/242 [==============================] - 0s 308us/step - loss: 0.6590 - mean_absolute_error: 0.6511 - mean_squared_error: 0.6590 - val_loss: 0.8349 - val_mean_absolute_error: 0.7247 - val_mean_squared_error: 0.8349
# Epoch 46/50
# 242/242 [==============================] - 0s 307us/step - loss: 0.6552 - mean_absolute_error: 0.6503 - mean_squared_error: 0.6552 - val_loss: 0.8237 - val_mean_absolute_error: 0.7200 - val_mean_squared_error: 0.8237
# Epoch 47/50
# 242/242 [==============================] - 0s 303us/step - loss: 0.6534 - mean_absolute_error: 0.6482 - mean_squared_error: 0.6534 - val_loss: 0.8343 - val_mean_absolute_error: 0.7239 - val_mean_squared_error: 0.8343
# Epoch 48/50
# 242/242 [==============================] - 0s 332us/step - loss: 0.6522 - mean_absolute_error: 0.6470 - mean_squared_error: 0.6522 - val_loss: 0.8304 - val_mean_absolute_error: 0.7222 - val_mean_squared_error: 0.8304
# Epoch 49/50
# 242/242 [==============================] - 0s 309us/step - loss: 0.6522 - mean_absolute_error: 0.6456 - mean_squared_error: 0.6522 - val_loss: 0.8059 - val_mean_absolute_error: 0.7122 - val_mean_squared_error: 0.8059
# Epoch 50/50
# 242/242 [==============================] - 0s 311us/step - loss: 0.6514 - mean_absolute_error: 0.6483 - mean_squared_error: 0.6514 - val_loss: 0.8279 - val_mean_absolute_error: 0.7209 - val_mean_squared_error: 0.8279

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.8024753206317592
# 0.9098910646445333

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.989315390586853, p = 0.07074170559644699
# Test k = 0.9653554558753967, p = 0.08162524551153183

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9863134026527405, p_s = 0.00563850300386548
# k_n = 7.0559066981849465, p_n = 0.02936495421750998

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('2_SimpleNeuralNetwork.h5')
