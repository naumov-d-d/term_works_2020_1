# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>cp</th>
#       <th>trestbps</th>
#       <th>chol</th>
#       <th>fbs</th>
#       <th>restecg</th>
#       <th>thalach</th>
#       <th>exang</th>
#       <th>oldpeak</th>
#       <th>slope</th>
#       <th>ca</th>
#       <th>num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.927622</td>
#       <td>1.0</td>
#       <td>1.000000</td>
#       <td>0.624287</td>
#       <td>-0.206993</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>0.090789</td>
#       <td>0.0</td>
#       <td>0.552201</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-2.117138</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.454038</td>
#       <td>0.159591</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.444548</td>
#       <td>0.0</td>
#       <td>0.715169</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1.529863</td>
#       <td>0.0</td>
#       <td>0.577350</td>
#       <td>0.454038</td>
#       <td>-0.864692</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.931137</td>
#       <td>0.0</td>
#       <td>0.398844</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.253797</td>
#       <td>1.0</td>
#       <td>0.577350</td>
#       <td>0.335019</td>
#       <td>-0.141353</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.141680</td>
#       <td>0.0</td>
#       <td>0.265991</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.355054</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.335019</td>
#       <td>2.100829</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.601134</td>
#       <td>1.0</td>
#       <td>0.210865</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.355054</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>0.568560</td>
#       <td>-1.150460</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.008368</td>
#       <td>0.0</td>
#       <td>0.145476</td>
#       <td>0.707107</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.253797</td>
#       <td>0.0</td>
#       <td>0.577350</td>
#       <td>0.568560</td>
#       <td>1.054214</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.212382</td>
#       <td>0.0</td>
#       <td>0.379044</td>
#       <td>0.707107</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-1.125867</td>
#       <td>1.0</td>
#       <td>0.577350</td>
#       <td>0.335019</td>
#       <td>0.431579</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.966733</td>
#       <td>0.0</td>
#       <td>0.323580</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.170168</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.909866</td>
#       <td>-0.982712</td>
#       <td>1.0</td>
#       <td>0.397544</td>
#       <td>0.563348</td>
#       <td>0.0</td>
#       <td>0.179818</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.355054</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.679061</td>
#       <td>-1.750157</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.002123</td>
#       <td>0.0</td>
#       <td>0.436427</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
X = dataset.iloc[:, [*range(1,13),12]].values
Y = dataset['age'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
input_layer_size = 13
first_hidden_layer_size = 12
second_hidden_layer_size = 12
output_layer_size = 1
epochs_number = 50
batch_size = 4

# %%
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - softmax
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='softmax'))

model.add(Dense(second_hidden_layer_size, activation='softmax'))

model.add(Dense(output_layer_size, activation='linear'))

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 242 samples, validate on 61 samples
# Epoch 1/50
# 242/242 [==============================] - 0s 884us/step - loss: 0.9786 - mean_absolute_error: 0.8012 - mean_squared_error: 0.9786 - val_loss: 1.0495 - val_mean_absolute_error: 0.8576 - val_mean_squared_error: 1.0495
# Epoch 2/50
# 242/242 [==============================] - 0s 310us/step - loss: 0.9712 - mean_absolute_error: 0.7942 - mean_squared_error: 0.9712 - val_loss: 1.0474 - val_mean_absolute_error: 0.8538 - val_mean_squared_error: 1.0474
# Epoch 3/50
# 242/242 [==============================] - 0s 307us/step - loss: 0.9652 - mean_absolute_error: 0.7903 - mean_squared_error: 0.9652 - val_loss: 1.0424 - val_mean_absolute_error: 0.8509 - val_mean_squared_error: 1.0424
# Epoch 4/50
# 242/242 [==============================] - 0s 306us/step - loss: 0.9578 - mean_absolute_error: 0.7850 - mean_squared_error: 0.9578 - val_loss: 1.0370 - val_mean_absolute_error: 0.8469 - val_mean_squared_error: 1.0370
# Epoch 5/50
# 242/242 [==============================] - 0s 315us/step - loss: 0.9478 - mean_absolute_error: 0.7811 - mean_squared_error: 0.9478 - val_loss: 1.0278 - val_mean_absolute_error: 0.8423 - val_mean_squared_error: 1.0278
# Epoch 6/50
# 242/242 [==============================] - 0s 309us/step - loss: 0.9362 - mean_absolute_error: 0.7754 - mean_squared_error: 0.9362 - val_loss: 1.0135 - val_mean_absolute_error: 0.8364 - val_mean_squared_error: 1.0136
# Epoch 7/50
# 242/242 [==============================] - 0s 316us/step - loss: 0.9223 - mean_absolute_error: 0.7684 - mean_squared_error: 0.9223 - val_loss: 1.0017 - val_mean_absolute_error: 0.8292 - val_mean_squared_error: 1.0017
# Epoch 8/50
# 242/242 [==============================] - 0s 312us/step - loss: 0.9067 - mean_absolute_error: 0.7593 - mean_squared_error: 0.9067 - val_loss: 0.9862 - val_mean_absolute_error: 0.8220 - val_mean_squared_error: 0.9862
# Epoch 9/50
# 242/242 [==============================] - 0s 319us/step - loss: 0.8897 - mean_absolute_error: 0.7522 - mean_squared_error: 0.8897 - val_loss: 0.9731 - val_mean_absolute_error: 0.8153 - val_mean_squared_error: 0.9731
# Epoch 10/50
# 242/242 [==============================] - 0s 315us/step - loss: 0.8718 - mean_absolute_error: 0.7417 - mean_squared_error: 0.8718 - val_loss: 0.9566 - val_mean_absolute_error: 0.8085 - val_mean_squared_error: 0.9566
# Epoch 11/50
# 242/242 [==============================] - 0s 315us/step - loss: 0.8566 - mean_absolute_error: 0.7370 - mean_squared_error: 0.8566 - val_loss: 0.9410 - val_mean_absolute_error: 0.8022 - val_mean_squared_error: 0.9410
# Epoch 12/50
# 242/242 [==============================] - 0s 309us/step - loss: 0.8386 - mean_absolute_error: 0.7262 - mean_squared_error: 0.8386 - val_loss: 0.9348 - val_mean_absolute_error: 0.7966 - val_mean_squared_error: 0.9348
# Epoch 13/50
# 242/242 [==============================] - 0s 316us/step - loss: 0.8221 - mean_absolute_error: 0.7199 - mean_squared_error: 0.8221 - val_loss: 0.9163 - val_mean_absolute_error: 0.7891 - val_mean_squared_error: 0.9163
# Epoch 14/50
# 242/242 [==============================] - 0s 316us/step - loss: 0.8069 - mean_absolute_error: 0.7120 - mean_squared_error: 0.8069 - val_loss: 0.9040 - val_mean_absolute_error: 0.7832 - val_mean_squared_error: 0.9040
# Epoch 15/50
# 242/242 [==============================] - 0s 312us/step - loss: 0.7921 - mean_absolute_error: 0.7067 - mean_squared_error: 0.7921 - val_loss: 0.8947 - val_mean_absolute_error: 0.7777 - val_mean_squared_error: 0.8947
# Epoch 16/50
# 242/242 [==============================] - 0s 308us/step - loss: 0.7793 - mean_absolute_error: 0.7004 - mean_squared_error: 0.7793 - val_loss: 0.8834 - val_mean_absolute_error: 0.7716 - val_mean_squared_error: 0.8834
# Epoch 17/50
# 242/242 [==============================] - 0s 325us/step - loss: 0.7658 - mean_absolute_error: 0.6946 - mean_squared_error: 0.7658 - val_loss: 0.8716 - val_mean_absolute_error: 0.7656 - val_mean_squared_error: 0.8716
# Epoch 18/50
# 242/242 [==============================] - 0s 311us/step - loss: 0.7554 - mean_absolute_error: 0.6891 - mean_squared_error: 0.7554 - val_loss: 0.8649 - val_mean_absolute_error: 0.7610 - val_mean_squared_error: 0.8649
# Epoch 19/50
# 242/242 [==============================] - 0s 320us/step - loss: 0.7449 - mean_absolute_error: 0.6843 - mean_squared_error: 0.7449 - val_loss: 0.8572 - val_mean_absolute_error: 0.7569 - val_mean_squared_error: 0.8572
# Epoch 20/50
# 242/242 [==============================] - 0s 315us/step - loss: 0.7362 - mean_absolute_error: 0.6804 - mean_squared_error: 0.7362 - val_loss: 0.8472 - val_mean_absolute_error: 0.7507 - val_mean_squared_error: 0.8472
# Epoch 21/50
# 242/242 [==============================] - 0s 318us/step - loss: 0.7273 - mean_absolute_error: 0.6767 - mean_squared_error: 0.7273 - val_loss: 0.8439 - val_mean_absolute_error: 0.7475 - val_mean_squared_error: 0.8439
# Epoch 22/50
# 242/242 [==============================] - 0s 320us/step - loss: 0.7196 - mean_absolute_error: 0.6718 - mean_squared_error: 0.7196 - val_loss: 0.8392 - val_mean_absolute_error: 0.7434 - val_mean_squared_error: 0.8392
# Epoch 23/50
# 242/242 [==============================] - 0s 319us/step - loss: 0.7125 - mean_absolute_error: 0.6682 - mean_squared_error: 0.7125 - val_loss: 0.8345 - val_mean_absolute_error: 0.7407 - val_mean_squared_error: 0.8345
# Epoch 24/50
# 242/242 [==============================] - 0s 310us/step - loss: 0.7065 - mean_absolute_error: 0.6639 - mean_squared_error: 0.7065 - val_loss: 0.8304 - val_mean_absolute_error: 0.7373 - val_mean_squared_error: 0.8304
# Epoch 25/50
# 242/242 [==============================] - 0s 313us/step - loss: 0.7020 - mean_absolute_error: 0.6605 - mean_squared_error: 0.7020 - val_loss: 0.8336 - val_mean_absolute_error: 0.7361 - val_mean_squared_error: 0.8336
# Epoch 26/50
# 242/242 [==============================] - 0s 315us/step - loss: 0.6963 - mean_absolute_error: 0.6583 - mean_squared_error: 0.6963 - val_loss: 0.8258 - val_mean_absolute_error: 0.7339 - val_mean_squared_error: 0.8258
# Epoch 27/50
# 242/242 [==============================] - 0s 321us/step - loss: 0.6916 - mean_absolute_error: 0.6554 - mean_squared_error: 0.6916 - val_loss: 0.8268 - val_mean_absolute_error: 0.7331 - val_mean_squared_error: 0.8268
# Epoch 28/50
# 242/242 [==============================] - 0s 317us/step - loss: 0.6860 - mean_absolute_error: 0.6529 - mean_squared_error: 0.6860 - val_loss: 0.8190 - val_mean_absolute_error: 0.7306 - val_mean_squared_error: 0.8190
# Epoch 29/50
# 242/242 [==============================] - 0s 315us/step - loss: 0.6831 - mean_absolute_error: 0.6513 - mean_squared_error: 0.6831 - val_loss: 0.8182 - val_mean_absolute_error: 0.7302 - val_mean_squared_error: 0.8182
# Epoch 30/50
# 242/242 [==============================] - 0s 317us/step - loss: 0.6790 - mean_absolute_error: 0.6493 - mean_squared_error: 0.6790 - val_loss: 0.8092 - val_mean_absolute_error: 0.7266 - val_mean_squared_error: 0.8092
# Epoch 31/50
# 242/242 [==============================] - 0s 310us/step - loss: 0.6745 - mean_absolute_error: 0.6476 - mean_squared_error: 0.6745 - val_loss: 0.8094 - val_mean_absolute_error: 0.7257 - val_mean_squared_error: 0.8094
# Epoch 32/50
# 242/242 [==============================] - 0s 311us/step - loss: 0.6725 - mean_absolute_error: 0.6457 - mean_squared_error: 0.6725 - val_loss: 0.8097 - val_mean_absolute_error: 0.7256 - val_mean_squared_error: 0.8097
# Epoch 33/50
# 242/242 [==============================] - 0s 311us/step - loss: 0.6685 - mean_absolute_error: 0.6439 - mean_squared_error: 0.6685 - val_loss: 0.8051 - val_mean_absolute_error: 0.7238 - val_mean_squared_error: 0.8051
# Epoch 34/50
# 242/242 [==============================] - 0s 310us/step - loss: 0.6655 - mean_absolute_error: 0.6418 - mean_squared_error: 0.6655 - val_loss: 0.8068 - val_mean_absolute_error: 0.7233 - val_mean_squared_error: 0.8068
# Epoch 35/50
# 242/242 [==============================] - 0s 313us/step - loss: 0.6615 - mean_absolute_error: 0.6406 - mean_squared_error: 0.6615 - val_loss: 0.8033 - val_mean_absolute_error: 0.7223 - val_mean_squared_error: 0.8033
# Epoch 36/50
# 242/242 [==============================] - 0s 316us/step - loss: 0.6598 - mean_absolute_error: 0.6378 - mean_squared_error: 0.6598 - val_loss: 0.8049 - val_mean_absolute_error: 0.7219 - val_mean_squared_error: 0.8049
# Epoch 37/50
# 242/242 [==============================] - 0s 309us/step - loss: 0.6559 - mean_absolute_error: 0.6370 - mean_squared_error: 0.6559 - val_loss: 0.7973 - val_mean_absolute_error: 0.7199 - val_mean_squared_error: 0.7973
# Epoch 38/50
# 242/242 [==============================] - 0s 312us/step - loss: 0.6542 - mean_absolute_error: 0.6351 - mean_squared_error: 0.6542 - val_loss: 0.8026 - val_mean_absolute_error: 0.7209 - val_mean_squared_error: 0.8026
# Epoch 39/50
# 242/242 [==============================] - 0s 316us/step - loss: 0.6497 - mean_absolute_error: 0.6338 - mean_squared_error: 0.6497 - val_loss: 0.7948 - val_mean_absolute_error: 0.7178 - val_mean_squared_error: 0.7948
# Epoch 40/50
# 242/242 [==============================] - 0s 310us/step - loss: 0.6481 - mean_absolute_error: 0.6332 - mean_squared_error: 0.6481 - val_loss: 0.7924 - val_mean_absolute_error: 0.7166 - val_mean_squared_error: 0.7924
# Epoch 41/50
# 242/242 [==============================] - 0s 313us/step - loss: 0.6451 - mean_absolute_error: 0.6315 - mean_squared_error: 0.6451 - val_loss: 0.7918 - val_mean_absolute_error: 0.7163 - val_mean_squared_error: 0.7918
# Epoch 42/50
# 242/242 [==============================] - 0s 314us/step - loss: 0.6418 - mean_absolute_error: 0.6296 - mean_squared_error: 0.6418 - val_loss: 0.7878 - val_mean_absolute_error: 0.7135 - val_mean_squared_error: 0.7878
# Epoch 43/50
# 242/242 [==============================] - 0s 309us/step - loss: 0.6392 - mean_absolute_error: 0.6286 - mean_squared_error: 0.6392 - val_loss: 0.7892 - val_mean_absolute_error: 0.7136 - val_mean_squared_error: 0.7892
# Epoch 44/50
# 242/242 [==============================] - 0s 310us/step - loss: 0.6352 - mean_absolute_error: 0.6261 - mean_squared_error: 0.6352 - val_loss: 0.7869 - val_mean_absolute_error: 0.7125 - val_mean_squared_error: 0.7869
# Epoch 45/50
# 242/242 [==============================] - 0s 311us/step - loss: 0.6325 - mean_absolute_error: 0.6252 - mean_squared_error: 0.6325 - val_loss: 0.7822 - val_mean_absolute_error: 0.7098 - val_mean_squared_error: 0.7822
# Epoch 46/50
# 242/242 [==============================] - 0s 312us/step - loss: 0.6289 - mean_absolute_error: 0.6240 - mean_squared_error: 0.6289 - val_loss: 0.7873 - val_mean_absolute_error: 0.7105 - val_mean_squared_error: 0.7873
# Epoch 47/50
# 242/242 [==============================] - 0s 314us/step - loss: 0.6258 - mean_absolute_error: 0.6220 - mean_squared_error: 0.6258 - val_loss: 0.7865 - val_mean_absolute_error: 0.7090 - val_mean_squared_error: 0.7865
# Epoch 48/50
# 242/242 [==============================] - 0s 317us/step - loss: 0.6232 - mean_absolute_error: 0.6205 - mean_squared_error: 0.6232 - val_loss: 0.7884 - val_mean_absolute_error: 0.7084 - val_mean_squared_error: 0.7884
# Epoch 49/50
# 242/242 [==============================] - 0s 311us/step - loss: 0.6218 - mean_absolute_error: 0.6198 - mean_squared_error: 0.6218 - val_loss: 0.7873 - val_mean_absolute_error: 0.7066 - val_mean_squared_error: 0.7873
# Epoch 50/50
# 242/242 [==============================] - 0s 307us/step - loss: 0.6172 - mean_absolute_error: 0.6184 - mean_squared_error: 0.6172 - val_loss: 0.7845 - val_mean_absolute_error: 0.7052 - val_mean_squared_error: 0.7845

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.7829765936724747
# 0.8857450824000148

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.9836726784706116, p = 0.0070389811880886555
# Test k = 0.9789589643478394, p = 0.37511521577835083

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9833533763885498, p_s = 0.0013776090927422047
# k_n = 9.859217523095952, p_n = 0.007229331120477436

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('3_SimpleNeuralNetwork.h5')
