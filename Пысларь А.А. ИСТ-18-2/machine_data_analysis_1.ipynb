# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot
# Out:
# Using TensorFlow backend.

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
#    region  population      area       gdp  literacy  infant_mortality  \
# 0     0.0    0.883468  0.949292  0.023739  0.000000          0.469199
# 1     0.0    0.656127  0.716262  0.259141  0.613980          0.469199
# 2     0.0    0.889631  1.000000  0.319275  0.000000          0.312527
# 3     0.0    0.221791  0.344182  0.388712  0.907468          0.469199
# 4     0.0    0.243748  0.408165  0.669156  1.000000          0.469199
# 5     0.0    0.784492  0.998309  0.123009  0.000000          0.469199
# 6     0.0    0.068557  0.294178  0.407796  0.844982          0.469199
# 7     0.0    0.240608  0.404058  0.478170  0.653472          0.469199
# 8     0.0    0.909896  1.000000  0.483670  0.613980          0.469199
# 9     0.0    0.636643  0.718951  0.213241  0.613980          0.469199
#
#      arable  birthrate  deathrate
# 0  0.414029   0.302444        0.2
# 1  0.414029   0.302444        0.2
# 2  0.414029   0.302444        0.2
# 3  0.335106   0.302444        0.2
# 4  0.414029   0.302444        0.2
# 5  0.414029   0.302444        0.2
# 6  0.214318   0.302444        0.2
# 7  0.414029   0.302444        0.2
# 8  0.414029   0.302444        0.2
# 9  0.414029   0.302444        0.2

# %%
X = dataset.drop(columns=['population']).values
Y = dataset['population'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
# Задаем параметры структуры нейронной сети.


input_layer_size = 8


first_hidden_layer_size = 10
second_hidden_layer_size = 10

output_layer_size = 1


epochs_number = 40
batch_size = 16

# %%
# Создание нейронной сети прямого распространения, пока она пустая, т.е. не содержит слоёв и нейронов.
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

model.add(Dense(second_hidden_layer_size, activation='relu'))


model.add(Dense(output_layer_size, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                90
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 211
# Trainable params: 211
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 181 samples, validate on 46 samples
# Epoch 1/40
# 181/181 [==============================] - 0s 1ms/step - loss: 1.8177 - mean_absolute_error: 1.2893 - mean_squared_error: 1.8177 - val_loss: 1.3835 - val_mean_absolute_error: 1.1202 - val_mean_squared_error: 1.3835
# Epoch 2/40
# 181/181 [==============================] - 0s 436us/step - loss: 1.1820 - mean_absolute_error: 1.0277 - mean_squared_error: 1.1820 - val_loss: 0.8968 - val_mean_absolute_error: 0.8868 - val_mean_squared_error: 0.8968
# Epoch 3/40
# 181/181 [==============================] - 0s 475us/step - loss: 0.7784 - mean_absolute_error: 0.8219 - mean_squared_error: 0.7784 - val_loss: 0.5955 - val_mean_absolute_error: 0.7068 - val_mean_squared_error: 0.5955
# Epoch 4/40
# 181/181 [==============================] - 0s 260us/step - loss: 0.5266 - mean_absolute_error: 0.6623 - mean_squared_error: 0.5266 - val_loss: 0.4078 - val_mean_absolute_error: 0.5681 - val_mean_squared_error: 0.4078
# Epoch 5/40
# 181/181 [==============================] - 0s 412us/step - loss: 0.3589 - mean_absolute_error: 0.5324 - mean_squared_error: 0.3589 - val_loss: 0.2799 - val_mean_absolute_error: 0.4578 - val_mean_squared_error: 0.2799
# Epoch 6/40
# 181/181 [==============================] - 0s 420us/step - loss: 0.2418 - mean_absolute_error: 0.4239 - mean_squared_error: 0.2418 - val_loss: 0.1884 - val_mean_absolute_error: 0.3698 - val_mean_squared_error: 0.1884
# Epoch 7/40
# 181/181 [==============================] - 0s 256us/step - loss: 0.1640 - mean_absolute_error: 0.3388 - mean_squared_error: 0.1640 - val_loss: 0.1275 - val_mean_absolute_error: 0.3009 - val_mean_squared_error: 0.1275
# Epoch 8/40
# 181/181 [==============================] - 0s 387us/step - loss: 0.1158 - mean_absolute_error: 0.2737 - mean_squared_error: 0.1158 - val_loss: 0.0910 - val_mean_absolute_error: 0.2567 - val_mean_squared_error: 0.0910
# Epoch 9/40
# 181/181 [==============================] - 0s 328us/step - loss: 0.0898 - mean_absolute_error: 0.2334 - mean_squared_error: 0.0898 - val_loss: 0.0733 - val_mean_absolute_error: 0.2278 - val_mean_squared_error: 0.0733
# Epoch 10/40
# 181/181 [==============================] - 0s 137us/step - loss: 0.0765 - mean_absolute_error: 0.2129 - mean_squared_error: 0.0765 - val_loss: 0.0644 - val_mean_absolute_error: 0.2125 - val_mean_squared_error: 0.0644
# Epoch 11/40
# 181/181 [==============================] - 0s 138us/step - loss: 0.0692 - mean_absolute_error: 0.2029 - mean_squared_error: 0.0692 - val_loss: 0.0603 - val_mean_absolute_error: 0.2065 - val_mean_squared_error: 0.0603
# Epoch 12/40
# 181/181 [==============================] - 0s 301us/step - loss: 0.0649 - mean_absolute_error: 0.1968 - mean_squared_error: 0.0649 - val_loss: 0.0570 - val_mean_absolute_error: 0.2010 - val_mean_squared_error: 0.0570
# Epoch 13/40
# 181/181 [==============================] - 0s 110us/step - loss: 0.0608 - mean_absolute_error: 0.1910 - mean_squared_error: 0.0608 - val_loss: 0.0545 - val_mean_absolute_error: 0.1971 - val_mean_squared_error: 0.0545
# Epoch 14/40
# 181/181 [==============================] - 0s 109us/step - loss: 0.0577 - mean_absolute_error: 0.1864 - mean_squared_error: 0.0577 - val_loss: 0.0526 - val_mean_absolute_error: 0.1943 - val_mean_squared_error: 0.0526
# Epoch 15/40
# 181/181 [==============================] - 0s 263us/step - loss: 0.0548 - mean_absolute_error: 0.1832 - mean_squared_error: 0.0548 - val_loss: 0.0509 - val_mean_absolute_error: 0.1905 - val_mean_squared_error: 0.0509
# Epoch 16/40
# 181/181 [==============================] - 0s 103us/step - loss: 0.0524 - mean_absolute_error: 0.1800 - mean_squared_error: 0.0524 - val_loss: 0.0497 - val_mean_absolute_error: 0.1889 - val_mean_squared_error: 0.0497
# Epoch 17/40
# 181/181 [==============================] - 0s 110us/step - loss: 0.0505 - mean_absolute_error: 0.1777 - mean_squared_error: 0.0505 - val_loss: 0.0482 - val_mean_absolute_error: 0.1847 - val_mean_squared_error: 0.0482
# Epoch 18/40
# 181/181 [==============================] - 0s 275us/step - loss: 0.0486 - mean_absolute_error: 0.1752 - mean_squared_error: 0.0486 - val_loss: 0.0472 - val_mean_absolute_error: 0.1823 - val_mean_squared_error: 0.0472
# Epoch 19/40
# 181/181 [==============================] - 0s 109us/step - loss: 0.0473 - mean_absolute_error: 0.1739 - mean_squared_error: 0.0473 - val_loss: 0.0465 - val_mean_absolute_error: 0.1821 - val_mean_squared_error: 0.0465
# Epoch 20/40
# 181/181 [==============================] - 0s 121us/step - loss: 0.0458 - mean_absolute_error: 0.1715 - mean_squared_error: 0.0458 - val_loss: 0.0454 - val_mean_absolute_error: 0.1786 - val_mean_squared_error: 0.0454
# Epoch 21/40
# 181/181 [==============================] - 0s 119us/step - loss: 0.0444 - mean_absolute_error: 0.1694 - mean_squared_error: 0.0444 - val_loss: 0.0446 - val_mean_absolute_error: 0.1766 - val_mean_squared_error: 0.0446
# Epoch 22/40
# 181/181 [==============================] - 0s 112us/step - loss: 0.0433 - mean_absolute_error: 0.1678 - mean_squared_error: 0.0433 - val_loss: 0.0438 - val_mean_absolute_error: 0.1725 - val_mean_squared_error: 0.0438
# Epoch 23/40
# 181/181 [==============================] - 0s 117us/step - loss: 0.0420 - mean_absolute_error: 0.1652 - mean_squared_error: 0.0420 - val_loss: 0.0431 - val_mean_absolute_error: 0.1688 - val_mean_squared_error: 0.0431
# Epoch 24/40
# 181/181 [==============================] - 0s 333us/step - loss: 0.0411 - mean_absolute_error: 0.1635 - mean_squared_error: 0.0411 - val_loss: 0.0425 - val_mean_absolute_error: 0.1670 - val_mean_squared_error: 0.0425
# Epoch 25/40
# 181/181 [==============================] - 0s 107us/step - loss: 0.0402 - mean_absolute_error: 0.1621 - mean_squared_error: 0.0402 - val_loss: 0.0420 - val_mean_absolute_error: 0.1650 - val_mean_squared_error: 0.0420
# Epoch 26/40
# 181/181 [==============================] - 0s 117us/step - loss: 0.0393 - mean_absolute_error: 0.1611 - mean_squared_error: 0.0393 - val_loss: 0.0414 - val_mean_absolute_error: 0.1644 - val_mean_squared_error: 0.0414
# Epoch 27/40
# 181/181 [==============================] - 0s 285us/step - loss: 0.0385 - mean_absolute_error: 0.1593 - mean_squared_error: 0.0385 - val_loss: 0.0410 - val_mean_absolute_error: 0.1614 - val_mean_squared_error: 0.0410
# Epoch 28/40
# 181/181 [==============================] - 0s 123us/step - loss: 0.0378 - mean_absolute_error: 0.1578 - mean_squared_error: 0.0378 - val_loss: 0.0407 - val_mean_absolute_error: 0.1589 - val_mean_squared_error: 0.0407
# Epoch 29/40
# 181/181 [==============================] - 0s 110us/step - loss: 0.0372 - mean_absolute_error: 0.1565 - mean_squared_error: 0.0372 - val_loss: 0.0404 - val_mean_absolute_error: 0.1586 - val_mean_squared_error: 0.0404
# Epoch 30/40
# 181/181 [==============================] - 0s 285us/step - loss: 0.0366 - mean_absolute_error: 0.1554 - mean_squared_error: 0.0366 - val_loss: 0.0400 - val_mean_absolute_error: 0.1580 - val_mean_squared_error: 0.0400
# Epoch 31/40
# 181/181 [==============================] - 0s 105us/step - loss: 0.0360 - mean_absolute_error: 0.1543 - mean_squared_error: 0.0360 - val_loss: 0.0396 - val_mean_absolute_error: 0.1570 - val_mean_squared_error: 0.0396
# Epoch 32/40
# 181/181 [==============================] - 0s 98us/step - loss: 0.0355 - mean_absolute_error: 0.1528 - mean_squared_error: 0.0355 - val_loss: 0.0395 - val_mean_absolute_error: 0.1551 - val_mean_squared_error: 0.0395
# Epoch 33/40
# 181/181 [==============================] - 0s 349us/step - loss: 0.0350 - mean_absolute_error: 0.1515 - mean_squared_error: 0.0350 - val_loss: 0.0389 - val_mean_absolute_error: 0.1543 - val_mean_squared_error: 0.0389
# Epoch 34/40
# 181/181 [==============================] - 0s 123us/step - loss: 0.0344 - mean_absolute_error: 0.1506 - mean_squared_error: 0.0344 - val_loss: 0.0386 - val_mean_absolute_error: 0.1537 - val_mean_squared_error: 0.0386
# Epoch 35/40
# 181/181 [==============================] - 0s 113us/step - loss: 0.0341 - mean_absolute_error: 0.1499 - mean_squared_error: 0.0341 - val_loss: 0.0383 - val_mean_absolute_error: 0.1531 - val_mean_squared_error: 0.0383
# Epoch 36/40
# 181/181 [==============================] - 0s 328us/step - loss: 0.0335 - mean_absolute_error: 0.1483 - mean_squared_error: 0.0335 - val_loss: 0.0381 - val_mean_absolute_error: 0.1517 - val_mean_squared_error: 0.0381
# Epoch 37/40
# 181/181 [==============================] - 0s 143us/step - loss: 0.0330 - mean_absolute_error: 0.1468 - mean_squared_error: 0.0330 - val_loss: 0.0379 - val_mean_absolute_error: 0.1510 - val_mean_squared_error: 0.0379
# Epoch 38/40
# 181/181 [==============================] - 0s 292us/step - loss: 0.0328 - mean_absolute_error: 0.1465 - mean_squared_error: 0.0328 - val_loss: 0.0375 - val_mean_absolute_error: 0.1507 - val_mean_squared_error: 0.0375
# Epoch 39/40
# 181/181 [==============================] - 0s 103us/step - loss: 0.0322 - mean_absolute_error: 0.1452 - mean_squared_error: 0.0322 - val_loss: 0.0372 - val_mean_absolute_error: 0.1500 - val_mean_squared_error: 0.0372
# Epoch 40/40
# 181/181 [==============================] - 0s 116us/step - loss: 0.0318 - mean_absolute_error: 0.1445 - mean_squared_error: 0.0318 - val_loss: 0.0366 - val_mean_absolute_error: 0.1497 - val_mean_squared_error: 0.0366

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.17736006262245324
# 0.1912047946077018

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.9903678297996521, p = 0.2638532519340515
# Test k = 0.9605687260627747, p = 0.12063676118850708

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9874329566955566, p_s = 0.043503083288669586
# k_n = 5.008967799026507, p_n = 0.08171776168058494

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('SimpleNeuralNetwork.h5')
