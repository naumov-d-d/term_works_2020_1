# %%
# Загрузка зависимостей
import numpy
import pandas
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot

# %%
# Загрузка подготовленного набора данных
dataset = pandas.read_csv('prepared_data.csv') # Убедиться в правильности пути к файлу!
dataset.head(10) # Вывод первых 10 строк
# Out:
#        tpsa     saacc     h-050     mlogp     rdchi    gats1p        nn  \
# 0  0.514570  0.411306  0.000000  0.019635 -1.875809 -0.955340  0.001262
# 1  0.514570  0.411306  0.000000  0.159062 -1.554684 -1.066755  0.001262
# 2  0.123412  0.107901  0.000000  1.745911  0.652219 -1.568754  0.001262
# 3  0.123412  0.107901  0.000000  1.598251  0.599535 -1.535789  0.001262
# 4  0.123412  0.107901  0.000000  0.954059  0.439081 -0.868297  0.001262
# 5  1.000000  1.000000  0.375897 -2.248683  2.363947  0.778006  0.001262
# 6  0.123412  0.107901  0.000000  0.211611 -0.134453  0.392174  0.001262
# 7  0.514570  0.411306  0.000000  0.530092 -0.138569 -0.110742  0.001262
# 8  0.514570  0.411306  0.000000 -0.218431 -0.894383  0.590631  0.001262
# 9  0.514570  0.411306  0.000000  0.225688 -1.105498  0.925043  0.001262
#
#      c-040      lc50
# 0  0.00000 -0.455071
# 1  0.00000 -0.093061
# 2  0.00000  1.307301
# 3  0.00000  1.168207
# 4  0.00000  0.804428
# 5  0.85619  0.847093
# 6  0.00000  1.453502
# 7  0.00000 -0.231058
# 8  0.00000 -0.328732
# 9  0.00000 -0.411327

# %%
Xx = dataset.iloc[:, [*range(0,8)]] 
Xx.head(10)
# Out:
#        tpsa     saacc     h-050     mlogp     rdchi    gats1p        nn  \
# 0  0.514570  0.411306  0.000000  0.019635 -1.875809 -0.955340  0.001262
# 1  0.514570  0.411306  0.000000  0.159062 -1.554684 -1.066755  0.001262
# 2  0.123412  0.107901  0.000000  1.745911  0.652219 -1.568754  0.001262
# 3  0.123412  0.107901  0.000000  1.598251  0.599535 -1.535789  0.001262
# 4  0.123412  0.107901  0.000000  0.954059  0.439081 -0.868297  0.001262
# 5  1.000000  1.000000  0.375897 -2.248683  2.363947  0.778006  0.001262
# 6  0.123412  0.107901  0.000000  0.211611 -0.134453  0.392174  0.001262
# 7  0.514570  0.411306  0.000000  0.530092 -0.138569 -0.110742  0.001262
# 8  0.514570  0.411306  0.000000 -0.218431 -0.894383  0.590631  0.001262
# 9  0.514570  0.411306  0.000000  0.225688 -1.105498  0.925043  0.001262
#
#      c-040
# 0  0.00000
# 1  0.00000
# 2  0.00000
# 3  0.00000
# 4  0.00000
# 5  0.85619
# 6  0.00000
# 7  0.00000
# 8  0.00000
# 9  0.00000

# %%
# Выделение входных и выходных параметров:
# Выходной параметр - значение столбца обработанного набора данных, соответсвующее столбцу №8 из первоначального набора данных (machine.data.csv).
# Входные параметры - все остальные столбцы обработанного набора данных.
# Используем .values, чтобы индексы не попали в новые переменные и в дальнейшем не мешали нам, например, при построении графиков.
X = dataset.iloc[:, [*range(0,8)]].values
Y = dataset['lc50'].values

# Обратите внимание на структуру вашего обработанного файлы и измените индексы, если нужно.

# %%
# Разделение данных на обучающую и тестовую выборки:
# Используем метод train_test_split библиотеки sklearn.
# Он разделяет заданные массивы входных и выходных параметров на две части каждый.
# Значение test_size определяет долю тестовой выборки в исходных данных.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
# Задаем параметры структуры нейронной сети.

# Количество нейронов во входном слое должно быть равно количеству входных параметров.
input_layer_size = 8

# Количество нейронов в каждом скрытом слое и количество таких слоёв могут быть выбраны произвольно.
# Увеличение числа нейронов относительно предыдущего слоя позволяет лучше обрабатывать отдельные примеры.
# Уменьшение числа нейронов относительно предыдущего слоя позволяет обощать информацию и выводить новые правила.
# Увеличение числа слоёв помогает сети работать как более сложная функция.
first_hidden_layer_size = 6
second_hidden_layer_size = 6

# Количество нейронов в выходном слое должно быть равно количеству выходных параметров.
output_layer_size = 1

# Параметры обучения нейронной сети: количество эпох и размер батча.
epochs_number = 50
batch_size = 8

# %%
# Создание нейронной сети прямого распространения, пока она пустая, т.е. не содержит слоёв и нейронов.
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

# Второй скрытый слой, функция активации - ReLU
model.add(Dense(second_hidden_layer_size, activation='relu'))

# Выходной слой, функция активации - линейная, т.к. решается задача регрессии.
model.add(Dense(output_layer_size, activation='linear'))

# %%
# Обзор нейронной сети, теперь в ней есть слои и нейроны.
# Если внимательно посмотреть на количество параметров, т.е. связей между нейронами, то можно увидеть, что автоматически добавлены нейроны смещения.
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dense_20 (Dense)             (None, 6)                 42
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 103
# Trainable params: 103
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Настройка нейронной сети.
# Функция потерь (loss) - среднеквадратическая ошибка.
# Оптимизатор (optimizer) - adam (в настоящий момент - это стандартный оптимизатор).
# Указываем метрики средняя абсолютная ошибка (mean_absolute_error) и среднеквадратическая ошиба (mean_squared_error) для дальнейшего анализа.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
# На вход передаем обучающие и тестовые выборки, количество эпох и размер батча.
# На выходе получаем объект с историей обучения, который далее будем анализировать.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 436 samples, validate on 110 samples
# Epoch 1/50
# 436/436 [==============================] - 0s 1ms/step - loss: 1.3253 - mean_absolute_error: 0.8619 - mean_squared_error: 1.3253 - val_loss: 1.0423 - val_mean_absolute_error: 0.7790 - val_mean_squared_error: 1.0423
# Epoch 2/50
# 436/436 [==============================] - 0s 799us/step - loss: 1.0823 - mean_absolute_error: 0.7756 - mean_squared_error: 1.0823 - val_loss: 0.8867 - val_mean_absolute_error: 0.7232 - val_mean_squared_error: 0.8867
# Epoch 3/50
# 436/436 [==============================] - 0s 399us/step - loss: 0.9537 - mean_absolute_error: 0.7226 - mean_squared_error: 0.9537 - val_loss: 0.8144 - val_mean_absolute_error: 0.6961 - val_mean_squared_error: 0.8144
# Epoch 4/50
# 436/436 [==============================] - 0s 339us/step - loss: 0.8611 - mean_absolute_error: 0.6859 - mean_squared_error: 0.8611 - val_loss: 0.7639 - val_mean_absolute_error: 0.6735 - val_mean_squared_error: 0.7639
# Epoch 5/50
# 436/436 [==============================] - 0s 413us/step - loss: 0.7926 - mean_absolute_error: 0.6582 - mean_squared_error: 0.7926 - val_loss: 0.7272 - val_mean_absolute_error: 0.6552 - val_mean_squared_error: 0.7272
# Epoch 6/50
# 436/436 [==============================] - 0s 305us/step - loss: 0.7432 - mean_absolute_error: 0.6445 - mean_squared_error: 0.7432 - val_loss: 0.7052 - val_mean_absolute_error: 0.6417 - val_mean_squared_error: 0.7052
# Epoch 7/50
# 436/436 [==============================] - 0s 339us/step - loss: 0.7035 - mean_absolute_error: 0.6314 - mean_squared_error: 0.7035 - val_loss: 0.6852 - val_mean_absolute_error: 0.6290 - val_mean_squared_error: 0.6852
# Epoch 8/50
# 436/436 [==============================] - 0s 427us/step - loss: 0.6769 - mean_absolute_error: 0.6206 - mean_squared_error: 0.6769 - val_loss: 0.6744 - val_mean_absolute_error: 0.6203 - val_mean_squared_error: 0.6744
# Epoch 9/50
# 436/436 [==============================] - 0s 420us/step - loss: 0.6576 - mean_absolute_error: 0.6121 - mean_squared_error: 0.6576 - val_loss: 0.6634 - val_mean_absolute_error: 0.6133 - val_mean_squared_error: 0.6634
# Epoch 10/50
# 436/436 [==============================] - 0s 305us/step - loss: 0.6450 - mean_absolute_error: 0.6081 - mean_squared_error: 0.6450 - val_loss: 0.6421 - val_mean_absolute_error: 0.6045 - val_mean_squared_error: 0.6421
# Epoch 11/50
# 436/436 [==============================] - 0s 412us/step - loss: 0.6334 - mean_absolute_error: 0.6036 - mean_squared_error: 0.6334 - val_loss: 0.6387 - val_mean_absolute_error: 0.6015 - val_mean_squared_error: 0.6387
# Epoch 12/50
# 436/436 [==============================] - 0s 405us/step - loss: 0.6243 - mean_absolute_error: 0.5996 - mean_squared_error: 0.6243 - val_loss: 0.6298 - val_mean_absolute_error: 0.5990 - val_mean_squared_error: 0.6298
# Epoch 13/50
# 436/436 [==============================] - 0s 308us/step - loss: 0.6190 - mean_absolute_error: 0.5979 - mean_squared_error: 0.6190 - val_loss: 0.6268 - val_mean_absolute_error: 0.5971 - val_mean_squared_error: 0.6268
# Epoch 14/50
# 436/436 [==============================] - 0s 402us/step - loss: 0.6119 - mean_absolute_error: 0.5947 - mean_squared_error: 0.6119 - val_loss: 0.6204 - val_mean_absolute_error: 0.5954 - val_mean_squared_error: 0.6204
# Epoch 15/50
# 436/436 [==============================] - 0s 378us/step - loss: 0.6073 - mean_absolute_error: 0.5914 - mean_squared_error: 0.6073 - val_loss: 0.6184 - val_mean_absolute_error: 0.5940 - val_mean_squared_error: 0.6184
# Epoch 16/50
# 436/436 [==============================] - 0s 328us/step - loss: 0.6048 - mean_absolute_error: 0.5913 - mean_squared_error: 0.6048 - val_loss: 0.6187 - val_mean_absolute_error: 0.5927 - val_mean_squared_error: 0.6187
# Epoch 17/50
# 436/436 [==============================] - 0s 388us/step - loss: 0.5978 - mean_absolute_error: 0.5878 - mean_squared_error: 0.5978 - val_loss: 0.6036 - val_mean_absolute_error: 0.5897 - val_mean_squared_error: 0.6036
# Epoch 18/50
# 436/436 [==============================] - 0s 315us/step - loss: 0.5954 - mean_absolute_error: 0.5858 - mean_squared_error: 0.5954 - val_loss: 0.6029 - val_mean_absolute_error: 0.5882 - val_mean_squared_error: 0.6029
# Epoch 19/50
# 436/436 [==============================] - 0s 393us/step - loss: 0.5898 - mean_absolute_error: 0.5824 - mean_squared_error: 0.5898 - val_loss: 0.6033 - val_mean_absolute_error: 0.5865 - val_mean_squared_error: 0.6033
# Epoch 20/50
# 436/436 [==============================] - 0s 408us/step - loss: 0.5872 - mean_absolute_error: 0.5810 - mean_squared_error: 0.5872 - val_loss: 0.5933 - val_mean_absolute_error: 0.5850 - val_mean_squared_error: 0.5933
# Epoch 21/50
# 436/436 [==============================] - 0s 297us/step - loss: 0.5822 - mean_absolute_error: 0.5786 - mean_squared_error: 0.5822 - val_loss: 0.5913 - val_mean_absolute_error: 0.5836 - val_mean_squared_error: 0.5913
# Epoch 22/50
# 436/436 [==============================] - 0s 409us/step - loss: 0.5781 - mean_absolute_error: 0.5765 - mean_squared_error: 0.5781 - val_loss: 0.5842 - val_mean_absolute_error: 0.5819 - val_mean_squared_error: 0.5842
# Epoch 23/50
# 436/436 [==============================] - 0s 395us/step - loss: 0.5754 - mean_absolute_error: 0.5753 - mean_squared_error: 0.5754 - val_loss: 0.5784 - val_mean_absolute_error: 0.5798 - val_mean_squared_error: 0.5784
# Epoch 24/50
# 436/436 [==============================] - 0s 315us/step - loss: 0.5708 - mean_absolute_error: 0.5715 - mean_squared_error: 0.5708 - val_loss: 0.5861 - val_mean_absolute_error: 0.5784 - val_mean_squared_error: 0.5861
# Epoch 25/50
# 436/436 [==============================] - 0s 388us/step - loss: 0.5683 - mean_absolute_error: 0.5700 - mean_squared_error: 0.5683 - val_loss: 0.5801 - val_mean_absolute_error: 0.5771 - val_mean_squared_error: 0.5801
# Epoch 26/50
# 436/436 [==============================] - 0s 292us/step - loss: 0.5651 - mean_absolute_error: 0.5679 - mean_squared_error: 0.5651 - val_loss: 0.5784 - val_mean_absolute_error: 0.5747 - val_mean_squared_error: 0.5784
# Epoch 27/50
# 436/436 [==============================] - 0s 408us/step - loss: 0.5631 - mean_absolute_error: 0.5673 - mean_squared_error: 0.5631 - val_loss: 0.5699 - val_mean_absolute_error: 0.5729 - val_mean_squared_error: 0.5699
# Epoch 28/50
# 436/436 [==============================] - 0s 304us/step - loss: 0.5577 - mean_absolute_error: 0.5629 - mean_squared_error: 0.5577 - val_loss: 0.5805 - val_mean_absolute_error: 0.5725 - val_mean_squared_error: 0.5805
# Epoch 29/50
# 436/436 [==============================] - 0s 380us/step - loss: 0.5561 - mean_absolute_error: 0.5622 - mean_squared_error: 0.5561 - val_loss: 0.5677 - val_mean_absolute_error: 0.5712 - val_mean_squared_error: 0.5677
# Epoch 30/50
# 436/436 [==============================] - 0s 412us/step - loss: 0.5517 - mean_absolute_error: 0.5602 - mean_squared_error: 0.5517 - val_loss: 0.5760 - val_mean_absolute_error: 0.5708 - val_mean_squared_error: 0.5760
# Epoch 31/50
# 436/436 [==============================] - 0s 323us/step - loss: 0.5523 - mean_absolute_error: 0.5622 - mean_squared_error: 0.5523 - val_loss: 0.5715 - val_mean_absolute_error: 0.5690 - val_mean_squared_error: 0.5715
# Epoch 32/50
# 436/436 [==============================] - 0s 368us/step - loss: 0.5479 - mean_absolute_error: 0.5570 - mean_squared_error: 0.5479 - val_loss: 0.5733 - val_mean_absolute_error: 0.5682 - val_mean_squared_error: 0.5733
# Epoch 33/50
# 436/436 [==============================] - 0s 295us/step - loss: 0.5446 - mean_absolute_error: 0.5567 - mean_squared_error: 0.5446 - val_loss: 0.5620 - val_mean_absolute_error: 0.5655 - val_mean_squared_error: 0.5620
# Epoch 34/50
# 436/436 [==============================] - 0s 398us/step - loss: 0.5443 - mean_absolute_error: 0.5584 - mean_squared_error: 0.5443 - val_loss: 0.5636 - val_mean_absolute_error: 0.5652 - val_mean_squared_error: 0.5636
# Epoch 35/50
# 436/436 [==============================] - 0s 298us/step - loss: 0.5443 - mean_absolute_error: 0.5557 - mean_squared_error: 0.5443 - val_loss: 0.5659 - val_mean_absolute_error: 0.5656 - val_mean_squared_error: 0.5659
# Epoch 36/50
# 436/436 [==============================] - 0s 381us/step - loss: 0.5420 - mean_absolute_error: 0.5569 - mean_squared_error: 0.5420 - val_loss: 0.5609 - val_mean_absolute_error: 0.5636 - val_mean_squared_error: 0.5609
# Epoch 37/50
# 436/436 [==============================] - 0s 297us/step - loss: 0.5373 - mean_absolute_error: 0.5532 - mean_squared_error: 0.5373 - val_loss: 0.5574 - val_mean_absolute_error: 0.5621 - val_mean_squared_error: 0.5574
# Epoch 38/50
# 436/436 [==============================] - 0s 373us/step - loss: 0.5371 - mean_absolute_error: 0.5533 - mean_squared_error: 0.5371 - val_loss: 0.5660 - val_mean_absolute_error: 0.5635 - val_mean_squared_error: 0.5660
# Epoch 39/50
# 436/436 [==============================] - 0s 305us/step - loss: 0.5344 - mean_absolute_error: 0.5503 - mean_squared_error: 0.5344 - val_loss: 0.5651 - val_mean_absolute_error: 0.5631 - val_mean_squared_error: 0.5651
# Epoch 40/50
# 436/436 [==============================] - 0s 375us/step - loss: 0.5347 - mean_absolute_error: 0.5509 - mean_squared_error: 0.5347 - val_loss: 0.5638 - val_mean_absolute_error: 0.5628 - val_mean_squared_error: 0.5638
# Epoch 41/50
# 436/436 [==============================] - 0s 321us/step - loss: 0.5319 - mean_absolute_error: 0.5490 - mean_squared_error: 0.5319 - val_loss: 0.5626 - val_mean_absolute_error: 0.5623 - val_mean_squared_error: 0.5626
# Epoch 42/50
# 436/436 [==============================] - 0s 348us/step - loss: 0.5295 - mean_absolute_error: 0.5480 - mean_squared_error: 0.5295 - val_loss: 0.5627 - val_mean_absolute_error: 0.5617 - val_mean_squared_error: 0.5627
# Epoch 43/50
# 436/436 [==============================] - 0s 293us/step - loss: 0.5289 - mean_absolute_error: 0.5479 - mean_squared_error: 0.5289 - val_loss: 0.5598 - val_mean_absolute_error: 0.5609 - val_mean_squared_error: 0.5598
# Epoch 44/50
# 436/436 [==============================] - 0s 378us/step - loss: 0.5300 - mean_absolute_error: 0.5476 - mean_squared_error: 0.5300 - val_loss: 0.5642 - val_mean_absolute_error: 0.5611 - val_mean_squared_error: 0.5642
# Epoch 45/50
# 436/436 [==============================] - 0s 306us/step - loss: 0.5270 - mean_absolute_error: 0.5488 - mean_squared_error: 0.5270 - val_loss: 0.5597 - val_mean_absolute_error: 0.5602 - val_mean_squared_error: 0.5597
# Epoch 46/50
# 436/436 [==============================] - 0s 389us/step - loss: 0.5233 - mean_absolute_error: 0.5445 - mean_squared_error: 0.5233 - val_loss: 0.5598 - val_mean_absolute_error: 0.5602 - val_mean_squared_error: 0.5598
# Epoch 47/50
# 436/436 [==============================] - 0s 431us/step - loss: 0.5233 - mean_absolute_error: 0.5456 - mean_squared_error: 0.5233 - val_loss: 0.5578 - val_mean_absolute_error: 0.5584 - val_mean_squared_error: 0.5578
# Epoch 48/50
# 436/436 [==============================] - 0s 301us/step - loss: 0.5215 - mean_absolute_error: 0.5438 - mean_squared_error: 0.5215 - val_loss: 0.5564 - val_mean_absolute_error: 0.5581 - val_mean_squared_error: 0.5564
# Epoch 49/50
# 436/436 [==============================] - 0s 387us/step - loss: 0.5182 - mean_absolute_error: 0.5443 - mean_squared_error: 0.5182 - val_loss: 0.5646 - val_mean_absolute_error: 0.5589 - val_mean_squared_error: 0.5646
# Epoch 50/50
# 436/436 [==============================] - 0s 457us/step - loss: 0.5175 - mean_absolute_error: 0.5425 - mean_squared_error: 0.5175 - val_loss: 0.5581 - val_mean_absolute_error: 0.5573 - val_mean_squared_error: 0.5581

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
# Видно, что в процессе обучения сеть с каждой эпохой вычисляет всё более точные прогнозы значений Y.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
# В идеальной ситуации они должны совпадать, т.е. точки (Y_train[i], Y_pred_train[i]) должны лежать на прямой Y_train = Y_pred_train.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([0,1], [0,1], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Таким образом, обучение по обучающей выборке проведено.
# Теперь проверим работу нейроной сети на тестовой выборке.

# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([0,1], [0,1], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Итого, качество работы нейронной сети на тестовых данных ниже, чем на обучающих - это ожидаемо.
# Тем не менее, нейронная сеть способна найти зависимости и предсказвать значение Y по X с приемлемым уровенм точности.

# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(numpy.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(numpy.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.7154955556396845
# 0.7470723161669394

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
# Для этого используем библиотеку scipy и метод stats.shapiro.
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.9837546348571777, p = 8.396177145186812e-05
# Test k = 0.9549078941345215, p = 0.0009377425885759294

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9809873700141907, p_s = 1.5075545434228843e-06
# k_n = 24.750228029387127, p_n = 4.2223698374093305e-06

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
# Можо также визульно убедиться, что распределения "почти нормальное".
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
# Сохраним обученную нейронную сеть, название файла можно выбрать любое, расширение - h5.
model.save('model1.h5')
